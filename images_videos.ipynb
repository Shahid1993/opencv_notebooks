# %% [markdown]
# ## Reading and Loading Images with OpenCV and NumPy

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
panda_img = cv2.imread('./data/pandas.jpg')
print(panda_img.shape)
panda_gray_img = cv2.cvtColor(panda_img, cv2.COLOR_BGR2GRAY)

#cv2.imshow("Color Panda", panda_img)
plt.imshow(panda_img)
plt.title('Color Panda')
plt.show()

#cv2.imshow("Grey Panda", panda_gray_img)
plt.imshow(panda_gray_img)
plt.title('Grey Panda')
plt.show()

cv2.imwrite('gray_panda', panda_gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (900, 900, 3)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-6a4b63132a77> in <module>
#      13 plt.show()
#      14
# ---> 15 cv2.imwrite('gray_panda', panda_gray_img)
#      16 cv2.waitKey(0)
#      17 cv2.destroyAllWindows()
#
# error: OpenCV(3.4.1) C:\Miniconda3\conda-bld\opencv-suite_1533128839831\work\modules\imgcodecs\src\loadsave.cpp:678: error: (-2) could not find a writer for the specified extension in function cv::imwrite_
